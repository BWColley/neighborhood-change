# %% [markdown]
# (c) Karen Belita  <br />
# Team Neighborhood Change <br />
# Last Updated 9/7/2016 <br />
#
# # NOTEBOOK: FEATURE SELECTION & MODEL SELECTION-IMPUTER-INTERPOLATE
# * This is to chose the best feature selecton method and model selection method

# %% [markdown]
# ## DEPENDENCIES
# indicators.csv --  which has a list of all features from the PostgreSQL database

# %%
import pandas as pd
import os 
import csv
import xlrd
import numpy as np
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix
from __future__ import print_function

from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import Imputer
from sklearn import preprocessing
matplotlib.style.use('ggplot')
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
## http://stats.stackexchange.com/questions/89809/is-it-important-to-scale-data-before-clustering
# above says that scaling makes for better

from time import time
import numpy as np
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# %matplotlib inline 

from sklearn.cluster import AgglomerativeClustering
import warnings

# %% [markdown]
# ## Part 1:
# * read indicators csv into pandas dataframe
# * remove unnecessary columns
# * convert Nans into blank space
# * imputed missing data using interpolate function from pandas

# %%
df = pd.read_csv('indicators.csv')

# %%
indicators = df[['cbsa', 'msa_name', 'violent_crime_rate', 
                'murder_manslaughter',
                'rape', 'robbery',
                'aggravated_assault',
                'property_crime_rate',
                'burglary', 'larceny_theft',
                'motor_vehicle_theft',
                'total_crime_rate',
                'median_gross_rent',
                'median_monthly_mortgage',
                'rent_burden', 'mortgage_burden',
                'income_change_2012_to_2014',
                'median_age_of_men', 'median_age_of_women',
                'median_age', 'median_household_income',
                'single_men_population',
                'single_women_population',
                'ratio_of_single_men_to_single_women',
                'population_percent_of_single_men',
                'population_percent_of_single_women',
                'population', 'edu_average_scale_score',
                'pct_laccess_pop10', 'pct_laccess_lowi10',
                'pct_laccess_child10', 'pct_laccess_seniors10',
                'pct_laccess_hhnv10', 'event_mpmt',
                'fatalities_mpmt', 'injuries_mpmt',
                'walk_score', 'transit_score', 'bike_score',
                'unemploymentrate', 'employment', 'laborforce']]

# %%
## all Nans to white space
indicators = indicators.replace(np.nan,' ', regex=True)
##convert to all floats
indicators = indicators.convert_objects(convert_numeric=True)
# Out:
# /Users/kbelita/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
indicators.columns = ['cbsa', 'msa_name', 'violent_crime_rate', 
                                'murder_manslaughter',
                                'rape', 'robbery',
                                'aggravated_assault',
                                'property_crime_rate',
                                'burglary', 'larceny_theft',
                                'motor_vehicle_theft',
                                'total_crime_rate',
                                'median_gross_rent',
                                'median_monthly_mortgage',
                                'rent_burden', 'mortgage_burden',
                                'income_change_2012_to_2014',
                                'median_age_of_men', 'median_age_of_women',
                                'median_age', 'median_household_income',
                                'single_men_population',
                                'single_women_population',
                                'ratio_of_single_men_to_single_women',
                                'population_percent_of_single_men',
                                'population_percent_of_single_women',
                                'population', 'edu_average_scale_score',
                                'pct_laccess_pop10', 'pct_laccess_lowi10',
                                'pct_laccess_child10', 'pct_laccess_seniors10',
                                'pct_laccess_hhnv10', 'event_mpmt',
                                'fatalities_mpmt', 'injuries_mpmt',
                                'walk_score', 'transit_score', 'bike_score',
                                'unemploymentrate', 'employment',
                                'laborforce']

# %%
featuresx = df[['violent_crime_rate', 
                'murder_manslaughter',
                'rape', 'robbery',
                'aggravated_assault',
                'property_crime_rate',
                'burglary', 'larceny_theft',
                'motor_vehicle_theft',
                'total_crime_rate',
                'median_gross_rent',
                'median_monthly_mortgage',
                'rent_burden', 'mortgage_burden',
                'income_change_2012_to_2014',
                'median_age_of_men', 'median_age_of_women',
                'median_age', 'median_household_income',
                'single_men_population',
                'single_women_population',
                'ratio_of_single_men_to_single_women',
                'population_percent_of_single_men',
                'population_percent_of_single_women',
                'population', 'edu_average_scale_score',
                'pct_laccess_pop10', 'pct_laccess_lowi10',
                'pct_laccess_child10', 'pct_laccess_seniors10',
                'pct_laccess_hhnv10', 'event_mpmt',
                'fatalities_mpmt', 'injuries_mpmt',
                'walk_score', 'transit_score', 'bike_score',
                'unemploymentrate', 'employment', 'laborforce']]

labelsx = df["cbsa"]

# %%
## all Nans to white space
featuresx = featuresx.replace(np.nan,' ', regex=True)
featuresx = featuresx.replace(np.nan,'NaN', regex=True)
##convert to all floats
featuresx = featuresx.convert_objects(convert_numeric=True)
##imputer
featuresx = featuresx.interpolate()
# Out:
# /Users/kbelita/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
featuresx.columns = ['violent_crime_rate', 'murder_manslaughter', 'rape', 'robbery', 'aggravated_assault', 'property_crime_rate', 'burglary', 'larceny_theft', 'motor_vehicle_theft', 'total_crime_rate', 'median_gross_rent', 'median_monthly_mortgage', 'rent_burden', 'mortgage_burden', 'income_change_2012_to_2014', 'median_age_of_men', 'median_age_of_women', 'median_age', 'median_household_income', 'single_men_population', 'single_women_population', 'ratio_of_single_men_to_single_women', 'population_percent_of_single_men', 'population_percent_of_single_women', 'population', 'edu_average_scale_score', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt', 'fatalities_mpmt', 'injuries_mpmt', 'walk_score', 'transit_score', 'bike_score', 'unemploymentrate', 'employment', 'laborforce']

# %%
featuresx.head()
# Out:
#    violent_crime_rate  murder_manslaughter  rape  robbery  aggravated_assault  \
# 0               371.4                  3.1  16.6    135.3               216.3
# 1               368.9                  4.4  21.6    136.6               206.2
# 2               380.1                  6.3  28.2    143.3               202.2
# 3               332.9                  4.4  31.8    120.8               175.8
# 4               567.4                  5.8  33.2    232.2               296.1
#
#    property_crime_rate  burglary  larceny_theft  motor_vehicle_theft  \
# 0               1609.9    220.80         1254.4                100.8
# 1               2050.4    402.80         1324.6                323.0
# 2               2135.4    361.70         1605.9                167.9
# 3               3036.4    525.15         2071.8                263.3
# 4               3208.1    688.60         2132.6                387.0
#
#    total_crime_rate     ...      pct_laccess_hhnv10  event_mpmt  \
# 0            1981.3     ...                0.338235    0.418116
# 1            2419.3     ...                0.224680    0.298524
# 2            2515.5     ...                0.473720    0.579050
# 3            3369.3     ...                0.650693    0.494725
# 4            3775.5     ...                3.322921    0.492627
#
#    fatalities_mpmt  injuries_mpmt  walk_score  transit_score  bike_score  \
# 0         0.005243       0.396239   74.500000      44.833333   30.333333
# 1         0.004415       0.345391   60.052632      19.368421   24.000000
# 2         0.004533       0.708461   49.700000      20.300000    7.000000
# 3         0.006083       0.583938   38.714286      19.714286   26.285714
# 4         0.001631       0.724259   29.000000       7.400000    9.800000
#
#    unemploymentrate  employment  laborforce
# 0              6.40   9324454.0   9965273.0
# 1              6.75   6932227.5   7426637.5
# 2              7.10   4540001.0   4888002.0
# 3              5.00   3357271.0   3534675.0
# 4              5.00   3079095.0   3239227.0
#
# [5 rows x 40 columns]

# %%
len(featuresx.columns)
# Out:
# 40

# %% [markdown]
# # Part 2:
# * Unscaled data
# * Loop through K-Means Clustering, K-Means MiniBatch, and then Aggomerative Clustering with linkage default ward.
# * Features used were subset through Lasso, Ridge and ElasticNet

# %%
print ('UNSCALED DATA')

range_n_clusters = range(4,10)

feat_models = [Lasso(), Ridge(), ElasticNet()]


for feat_model in feat_models:
    print(20 * '*')
    print ('Modeling used for feature selection : %9s'  % (feat_model))
    print(20 * '*')   
    
    model = feat_model
    sfm = SelectFromModel(model)
    sfm.fit(featuresx, labelsx)
    feat_names = (list(featuresx[sfm.get_support(indices=True)]))
    print (list(featuresx[sfm.get_support(indices=True)]))
    
    
    features = featuresx[feat_names]
    features = features.values
    


    for n_clusters in range_n_clusters:
        print ('number of clusters: %d' % (n_clusters))
        print(69 * '_')
        print('% 9s' % 'name'
              '    time  inertia    homo   compl  v-meas     ARI AMI  silhouette')


        def bench_clustering(estimator, name, data):
            t0 = time()
            estimator.fit(data)
            try: 
                print('% 9s   %.2fs    %i   %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
                  % (name, (time() - t0), estimator.inertia_,
                     metrics.homogeneity_score(labelsx, estimator.labels_),
                     metrics.completeness_score(labelsx, estimator.labels_),
                     metrics.v_measure_score(labelsx, estimator.labels_),
                     metrics.adjusted_rand_score(labelsx, estimator.labels_),
                     metrics.adjusted_mutual_info_score(labelsx,  estimator.labels_),
                     metrics.silhouette_score(data, estimator.labels_)))
            except AttributeError:
                print('% 9s   %.2fs   %9s    %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
                  % (name, (time() - t0), "Na",
                     metrics.homogeneity_score(labelsx, estimator.labels_),
                     metrics.completeness_score(labelsx, estimator.labels_),
                     metrics.v_measure_score(labelsx, estimator.labels_),
                     metrics.adjusted_rand_score(labelsx, estimator.labels_),
                     metrics.adjusted_mutual_info_score(labelsx,  estimator.labels_),
                     metrics.silhouette_score(data, estimator.labels_)))

        bench_clustering(KMeans(init='k-means++', n_clusters=n_clusters, n_init=12),
                  name="k-means", data=features)
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            bench_clustering(MiniBatchKMeans(init='k-means++', n_clusters=n_clusters, n_init=12,max_no_improvement=10, verbose=0,
                      random_state=0),
                  name="minibatchk-means", data=features)
        bench_clustering(AgglomerativeClustering(n_clusters=n_clusters, linkage='ward'),
                  name="Ward", data=features)   
        
        print(69 * '_')
# Out:
# UNSCALED DATA
# ********************
# Modeling used for feature selection : Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)
# ********************
# ['violent_crime_rate', 'murder_manslaughter', 'rape', 'robbery', 'aggravated_assault', 'property_crime_rate', 'burglary', 'larceny_theft', 'motor_vehicle_theft', 'total_crime_rate', 'median_gross_rent', 'median_monthly_mortgage', 'rent_burden', 'mortgage_burden', 'income_change_2012_to_2014', 'median_age_of_men', 'median_age_of_women', 'median_age', 'median_household_income', 'single_men_population', 'single_women_population', 'population_percent_of_single_men', 'population_percent_of_single_women', 'population', 'edu_average_scale_score', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt', 'fatalities_mpmt', 'injuries_mpmt', 'walk_score', 'transit_score', 'bike_score', 'unemploymentrate', 'employment', 'laborforce']
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.04s    113673701491134   0.089   1.000   0.163   0.000   0.000    0.795
# minibatchk-means   0.03s    115592694102796   0.097   1.000   0.177   0.000   0.000    0.781
#      Ward   0.01s          Na    0.083   1.000   0.153   0.000   0.000    0.791
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.05s    72526519738434   0.091   1.000   0.166   0.000   0.000    0.798
# minibatchk-means   0.04s    74050897853376   0.104   1.000   0.189   0.000   0.000    0.774
#      Ward   0.01s          Na    0.084   1.000   0.155   0.000   0.000    0.795
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.06s    48843095856064   0.165   1.000   0.283   0.000   0.000    0.683
# minibatchk-means   0.04s    51959584736475   0.151   1.000   0.262   0.000   0.000    0.686
#      Ward   0.01s          Na    0.146   1.000   0.255   0.000   0.000    0.688
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    32840566222973   0.172   1.000   0.293   0.000   0.000    0.687
# minibatchk-means   0.05s    35649852448665   0.171   1.000   0.292   0.000   0.000    0.684
#      Ward   0.01s          Na    0.147   1.000   0.256   0.000   0.000    0.692
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    19298555103210   0.171   1.000   0.293   0.000   0.000    0.695
# minibatchk-means   0.06s    351599210043984   0.330   1.000   0.497   0.000   0.000    0.405
#      Ward   0.01s          Na    0.152   1.000   0.263   0.000   0.000    0.693
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.06s    14014636847273   0.205   1.000   0.341   0.000   0.000    0.656
# minibatchk-means   0.06s    393038115788499   0.281   1.000   0.438   0.000   0.000    0.536
#      Ward   0.01s          Na    0.160   1.000   0.275   0.000   0.000    0.697
# _____________________________________________________________________
# ********************
# Modeling used for feature selection : Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
# ********************
# ['murder_manslaughter', 'rent_burden', 'median_age_of_men', 'median_age_of_women', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt', 'fatalities_mpmt', 'unemploymentrate']
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.09s    28405   0.196   1.000   0.328   0.000   0.000    0.234
# minibatchk-means   0.03s    28886   0.186   1.000   0.313   0.000   0.000    0.261
#      Ward   0.00s          Na    0.168   1.000   0.287   0.000   0.000    0.254
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    24724   0.218   1.000   0.357   0.000   0.000    0.248
# minibatchk-means   0.04s    25211   0.232   1.000   0.376   0.000   0.000    0.222
#      Ward   0.01s          Na    0.193   1.000   0.324   0.000   0.000    0.242
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.07s    21568   0.257   1.000   0.409   0.000   0.000    0.234
# minibatchk-means   0.04s    21647   0.253   1.000   0.404   0.000   0.000    0.235
#      Ward   0.00s          Na    0.261   1.000   0.414   0.000   0.000    0.173
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    18950   0.299   1.000   0.461   0.000   0.000    0.237
# minibatchk-means   0.05s    20057   0.306   1.000   0.469   0.000   0.000    0.217
#      Ward   0.01s          Na    0.281   1.000   0.439   0.000   0.000    0.186
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.10s    17346   0.328   1.000   0.494   0.000   0.000    0.224
# minibatchk-means   0.05s    17580   0.324   1.000   0.490   0.000   0.000    0.223
#      Ward   0.01s          Na    0.313   1.000   0.477   0.000   0.000    0.171
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    16241   0.347   1.000   0.515   0.000   0.000    0.223
# minibatchk-means   0.06s    17075   0.346   1.000   0.514   0.000   0.000    0.201
#      Ward   0.00s          Na    0.340   1.000   0.507   0.000   0.000    0.183
# _____________________________________________________________________
# ********************
# Modeling used for feature selection : ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)
# ********************
# ['murder_manslaughter', 'rent_burden', 'mortgage_burden', 'median_age_of_men', 'median_age_of_women', 'population_percent_of_single_men', 'population_percent_of_single_women', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt']
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    36038   0.195   1.000   0.326   0.000   0.000    0.208
# minibatchk-means   0.03s    36377   0.195   1.000   0.327   0.000   0.000    0.203
#      Ward   0.01s          Na    0.174   1.000   0.297   0.000   0.000    0.250
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.10s    32184   0.225   1.000   0.367   0.000   0.000    0.211
# minibatchk-means   0.06s    32699   0.215   1.000   0.354   0.000   0.000    0.214
#      Ward   0.01s          Na    0.199   1.000   0.331   0.000   0.000    0.248
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.10s    28408   0.276   1.000   0.432   0.000   0.000    0.212
# minibatchk-means   0.07s    30846   0.279   1.000   0.436   0.000   0.000    0.171
#      Ward   0.01s          Na    0.242   1.000   0.390   0.000   0.000    0.214
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.13s    25359   0.286   1.000   0.444   0.000   0.000    0.226
# minibatchk-means   0.06s    27210   0.297   1.000   0.458   0.000   0.000    0.194
#      Ward   0.00s          Na    0.281   1.000   0.438   0.000   0.000    0.198
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.19s    22715   0.299   1.000   0.460   0.000   0.000    0.229
# minibatchk-means   0.09s    24206   0.332   1.000   0.498   0.000   0.000    0.182
#      Ward   0.01s          Na    0.288   1.000   0.447   0.000   0.000    0.209
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.17s    20866   0.329   1.000   0.495   0.000   0.000    0.213
# minibatchk-means   0.08s    22794   0.351   1.000   0.519   0.000   0.000    0.179
#      Ward   0.01s          Na    0.331   1.000   0.498   0.000   0.000    0.202
# _____________________________________________________________________

# %% [markdown]
# # Part 2:
# * Features ran through Standard Scaler
# * Loop through K-Means Clustering, K-Means MiniBatch, and then Aggomerative Clustering with linkage default ward.
# * Features used were subset through Lasso, Ridge and ElasticNet

# %%
print (20 * '*')
print (20 * '*')
print ('DATA RAN THROUGH STANDARD SCALER')
print (20 * '*')
print (20 * '*')


#####################
## STANDARD SCALE ##
###################

standard_scaler = preprocessing.StandardScaler()
stdscaledfeat= standard_scaler.fit_transform(featuresx)  ## turns into scaled array
stdscaledfeatures = pd.DataFrame(stdscaledfeat) ## make array pd again
stdscaledfeatures.columns = ['violent_crime_rate', 'murder_manslaughter', 'rape', 'robbery', 'aggravated_assault', 'property_crime_rate', 'burglary', 'larceny_theft', 'motor_vehicle_theft', 'total_crime_rate', 'median_gross_rent', 'median_monthly_mortgage', 'rent_burden', 'mortgage_burden', 'income_change_2012_to_2014', 'median_age_of_men', 'median_age_of_women', 'median_age', 'median_household_income', 'single_men_population', 'single_women_population', 'ratio_of_single_men_to_single_women', 'population_percent_of_single_men', 'population_percent_of_single_women', 'population', 'edu_average_scale_score', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt', 'fatalities_mpmt', 'injuries_mpmt', 'walk_score', 'transit_score', 'bike_score', 'unemploymentrate', 'employment', 'laborforce']


###################################################
# standard scaled features variable is stdscaledfatures
#####################################################

range_n_clusters = range(4,10)
feat_models = [Lasso(), Ridge(), ElasticNet()]


for feat_model in feat_models:
    print(20 * '*')
    print ('Modeling used for feature selection : %9s'  % (feat_model))
    print(20 * '*')   
    

    model = feat_model
    sfm = SelectFromModel(model)
    sfm.fit(featuresx, labelsx)
    feat_names = (list(featuresx[sfm.get_support(indices=True)]))
    print (list(featuresx[sfm.get_support(indices=True)]))
    

    features = stdscaledfeatures[feat_names]
    features = features.values
    


    for n_clusters in range_n_clusters:
        print ('number of clusters: %d' % (n_clusters))
        print(69 * '_')
        print('% 9s' % 'name'
              '    time  inertia    homo   compl  v-meas     ARI AMI  silhouette')


        def bench_clustering(estimator, name, data):
            t0 = time()
            estimator.fit(data)
            try: 
                print('% 9s   %.2fs    %i   %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
                  % (name, (time() - t0), estimator.inertia_,
                     metrics.homogeneity_score(labelsx, estimator.labels_),
                     metrics.completeness_score(labelsx, estimator.labels_),
                     metrics.v_measure_score(labelsx, estimator.labels_),
                     metrics.adjusted_rand_score(labelsx, estimator.labels_),
                     metrics.adjusted_mutual_info_score(labelsx,  estimator.labels_),
                     metrics.silhouette_score(data, estimator.labels_)))
            except AttributeError:
                print('% 9s   %.2fs   %9s    %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
                  % (name, (time() - t0), "Na",
                     metrics.homogeneity_score(labelsx, estimator.labels_),
                     metrics.completeness_score(labelsx, estimator.labels_),
                     metrics.v_measure_score(labelsx, estimator.labels_),
                     metrics.adjusted_rand_score(labelsx, estimator.labels_),
                     metrics.adjusted_mutual_info_score(labelsx,  estimator.labels_),
                     metrics.silhouette_score(data, estimator.labels_)))

        bench_clustering(KMeans(init='k-means++', n_clusters=n_clusters, n_init=12),
                  name="k-means", data=features)
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            bench_clustering(MiniBatchKMeans(init='k-means++', n_clusters=n_clusters, n_init=12,max_no_improvement=10, verbose=0,
                      random_state=0),
                  name="minibatchk-means", data=features)
        bench_clustering(AgglomerativeClustering(n_clusters=n_clusters, linkage='ward'),
          name="Ward", data=features)   
    
        
        print(69 * '_')
# Out:
# ********************
# ********************
# DATA RAN THROUGH STANDARD SCALER
# ********************
# ********************
# ********************
# Modeling used for feature selection : Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)
# ********************
# ['violent_crime_rate', 'murder_manslaughter', 'rape', 'robbery', 'aggravated_assault', 'property_crime_rate', 'burglary', 'larceny_theft', 'motor_vehicle_theft', 'total_crime_rate', 'median_gross_rent', 'median_monthly_mortgage', 'rent_burden', 'mortgage_burden', 'income_change_2012_to_2014', 'median_age_of_men', 'median_age_of_women', 'median_age', 'median_household_income', 'single_men_population', 'single_women_population', 'population_percent_of_single_men', 'population_percent_of_single_women', 'population', 'edu_average_scale_score', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt', 'fatalities_mpmt', 'injuries_mpmt', 'walk_score', 'transit_score', 'bike_score', 'unemploymentrate', 'employment', 'laborforce']
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    8703   0.205   1.000   0.341   0.000   0.000    0.106
# minibatchk-means   0.04s    8948   0.232   1.000   0.377   0.000   0.000    0.086
#      Ward   0.01s          Na    0.166   1.000   0.284   0.000   0.000    0.098
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.17s    8223   0.237   1.000   0.383   0.000   0.000    0.129
# minibatchk-means   0.04s    8573   0.242   1.000   0.389   0.000   0.000    0.092
#      Ward   0.01s          Na    0.215   1.000   0.354   0.000   0.000    0.101
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.12s    7848   0.289   1.000   0.448   0.000   0.000    0.108
# minibatchk-means   0.06s    8066   0.268   1.000   0.422   0.000   0.000    0.108
#      Ward   0.07s          Na    0.252   1.000   0.403   0.000   0.000    0.105
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.15s    7512   0.301   1.000   0.462   0.000   0.000    0.099
# minibatchk-means   0.09s    7664   0.291   1.000   0.451   0.000   0.000    0.074
#      Ward   0.02s          Na    0.255   1.000   0.407   0.000   0.000    0.109
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.55s    7149   0.305   1.000   0.467   0.000   0.000    0.109
# minibatchk-means   0.18s    7332   0.315   1.000   0.479   0.000   0.000    0.094
#      Ward   0.02s          Na    0.278   1.000   0.435   0.000   0.000    0.107
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.25s    6843   0.324   1.000   0.490   0.000   0.000    0.096
# minibatchk-means   0.11s    7078   0.335   1.000   0.501   0.000   0.000    0.119
#      Ward   0.01s          Na    0.285   1.000   0.443   0.000   0.000    0.115
# _____________________________________________________________________
# ********************
# Modeling used for feature selection : Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
# ********************
# ['murder_manslaughter', 'rent_burden', 'median_age_of_men', 'median_age_of_women', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt', 'fatalities_mpmt', 'unemploymentrate']
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.11s    2499   0.218   1.000   0.358   0.000   0.000    0.156
# minibatchk-means   0.05s    2575   0.170   1.000   0.291   0.000   0.000    0.168
#      Ward   0.01s          Na    0.149   1.000   0.259   0.000   0.000    0.206
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    2268   0.209   1.000   0.346   0.000   0.000    0.163
# minibatchk-means   0.06s    2340   0.220   1.000   0.360   0.000   0.000    0.130
#      Ward   0.00s          Na    0.152   1.000   0.264   0.000   0.000    0.215
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.18s    2078   0.260   1.000   0.413   0.000   0.000    0.154
# minibatchk-means   0.07s    2114   0.230   1.000   0.374   0.000   0.000    0.142
#      Ward   0.00s          Na    0.236   1.000   0.382   0.000   0.000    0.119
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.14s    1909   0.276   1.000   0.433   0.000   0.000    0.149
# minibatchk-means   0.16s    1980   0.277   1.000   0.434   0.000   0.000    0.136
#      Ward   0.01s          Na    0.239   1.000   0.386   0.000   0.000    0.117
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.11s    1771   0.294   1.000   0.454   0.000   0.000    0.164
# minibatchk-means   0.07s    1962   0.329   1.000   0.495   0.000   0.000    0.107
#      Ward   0.00s          Na    0.279   1.000   0.436   0.000   0.000    0.112
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.12s    1640   0.291   1.000   0.450   0.000   0.000    0.178
# minibatchk-means   0.17s    1822   0.344   1.000   0.511   0.000   0.000    0.118
#      Ward   0.01s          Na    0.302   1.000   0.464   0.000   0.000    0.122
# _____________________________________________________________________
# ********************
# Modeling used for feature selection : ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)
# ********************
# ['murder_manslaughter', 'rent_burden', 'mortgage_burden', 'median_age_of_men', 'median_age_of_women', 'population_percent_of_single_men', 'population_percent_of_single_women', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt']
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.11s    2581   0.214   1.000   0.352   0.000   0.000    0.155
# minibatchk-means   0.03s    2691   0.196   1.000   0.328   0.000   0.000    0.141
#      Ward   0.00s          Na    0.199   1.000   0.332   0.000   0.000    0.143
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    2360   0.214   1.000   0.352   0.000   0.000    0.171
# minibatchk-means   0.11s    2387   0.226   1.000   0.369   0.000   0.000    0.154
#      Ward   0.01s          Na    0.203   1.000   0.337   0.000   0.000    0.152
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.14s    2216   0.266   1.000   0.421   0.000   0.000    0.126
# minibatchk-means   0.09s    2261   0.264   1.000   0.418   0.000   0.000    0.122
#      Ward   0.01s          Na    0.266   1.000   0.420   0.000   0.000    0.101
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.11s    2056   0.283   1.000   0.442   0.000   0.000    0.147
# minibatchk-means   0.06s    2149   0.260   1.000   0.413   0.000   0.000    0.149
#      Ward   0.01s          Na    0.269   1.000   0.424   0.000   0.000    0.101
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.09s    1943   0.317   1.000   0.481   0.000   0.000    0.136
# minibatchk-means   0.09s    2055   0.295   1.000   0.455   0.000   0.000    0.142
#      Ward   0.01s          Na    0.284   1.000   0.443   0.000   0.000    0.116
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.14s    1801   0.309   1.000   0.472   0.000   0.000    0.152
# minibatchk-means   0.10s    1894   0.331   1.000   0.498   0.000   0.000    0.132
#      Ward   0.01s          Na    0.292   1.000   0.452   0.000   0.000    0.124
# _____________________________________________________________________

# %% [markdown]
# # Part 3:
# * Features ran through MinMax Scaler
# * Loop through K-Means Clustering, K-Means MiniBatch, and then Aggomerative Clustering with linkage default ward.
# * Features used were subset through Lasso, Ridge and ElasticNet

# %%
print (20 * '*')
print (20 * '*')
print ('DATA RAN THROUGH MINMAX SCALE')
print (20 * '*')
print (20 * '*')


#####################
## STANDARD SCALE ##
###################



minmaxscaler = preprocessing.MinMaxScaler()
featz= minmaxscaler.fit_transform(featuresx)  ## turns into scaled array
mmscaledfeatures = pd.DataFrame(featz) ## make array pd again
mmscaledfeatures.columns = ['violent_crime_rate', 'murder_manslaughter', 'rape', 'robbery', 'aggravated_assault', 'property_crime_rate', 'burglary', 'larceny_theft', 'motor_vehicle_theft', 'total_crime_rate', 'median_gross_rent', 'median_monthly_mortgage', 'rent_burden', 'mortgage_burden', 'income_change_2012_to_2014', 'median_age_of_men', 'median_age_of_women', 'median_age', 'median_household_income', 'single_men_population', 'single_women_population', 'ratio_of_single_men_to_single_women', 'population_percent_of_single_men', 'population_percent_of_single_women', 'population', 'edu_average_scale_score', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt', 'fatalities_mpmt', 'injuries_mpmt', 'walk_score', 'transit_score', 'bike_score', 'unemploymentrate', 'employment', 'laborforce']


###################################################
# standard scaled features variable is stdscaledfatures
#####################################################

range_n_clusters = [4,5,6,7,8,9]
feat_models = [Lasso(), Ridge(), ElasticNet()]

for feat_model in feat_models:
    print(20 * '*')
    print ('Modeling used for feature selection : %9s'  % (feat_model))
    print(20 * '*')   
    
    
    model = feat_model
    sfm = SelectFromModel(model)
    sfm.fit(featuresx, labelsx)
    feat_names = (list(featuresx[sfm.get_support(indices=True)]))
    print (list(featuresx[sfm.get_support(indices=True)]))
    

    features = mmscaledfeatures[feat_names]
    features = features.values
    


    for n_clusters in range_n_clusters:
        print ('number of clusters: %d' % (n_clusters))
        print(69 * '_')
        print('% 9s' % 'name'
              '    time  inertia    homo   compl  v-meas     ARI AMI  silhouette')


        def bench_clustering(estimator, name, data):
            t0 = time()
            estimator.fit(data)
            try: 
                print('% 9s   %.2fs    %i   %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
                  % (name, (time() - t0), estimator.inertia_,
                     metrics.homogeneity_score(labelsx, estimator.labels_),
                     metrics.completeness_score(labelsx, estimator.labels_),
                     metrics.v_measure_score(labelsx, estimator.labels_),
                     metrics.adjusted_rand_score(labelsx, estimator.labels_),
                     metrics.adjusted_mutual_info_score(labelsx,  estimator.labels_),
                     metrics.silhouette_score(data, estimator.labels_)))
            except AttributeError:
                print('% 9s   %.2fs   %9s    %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
                  % (name, (time() - t0), "Na",
                     metrics.homogeneity_score(labelsx, estimator.labels_),
                     metrics.completeness_score(labelsx, estimator.labels_),
                     metrics.v_measure_score(labelsx, estimator.labels_),
                     metrics.adjusted_rand_score(labelsx, estimator.labels_),
                     metrics.adjusted_mutual_info_score(labelsx,  estimator.labels_),
                     metrics.silhouette_score(data, estimator.labels_)))

        bench_clustering(KMeans(init='k-means++', n_clusters=n_clusters, n_init=12),
                  name="k-means", data=features)
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            bench_clustering(MiniBatchKMeans(init='k-means++', n_clusters=n_clusters, n_init=12,max_no_improvement=10, verbose=0,
                      random_state=0),
                  name="minibatchk-means", data=features)
        bench_clustering(AgglomerativeClustering(n_clusters=n_clusters, linkage='ward'),
          name="Ward", data=features)   

        print(69 * '_')
# Out:
# ********************
# ********************
# DATA RAN THROUGH MINMAX SCALE
# ********************
# ********************
# ********************
# Modeling used for feature selection : Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)
# ********************
# ['violent_crime_rate', 'murder_manslaughter', 'rape', 'robbery', 'aggravated_assault', 'property_crime_rate', 'burglary', 'larceny_theft', 'motor_vehicle_theft', 'total_crime_rate', 'median_gross_rent', 'median_monthly_mortgage', 'rent_burden', 'mortgage_burden', 'income_change_2012_to_2014', 'median_age_of_men', 'median_age_of_women', 'median_age', 'median_household_income', 'single_men_population', 'single_women_population', 'population_percent_of_single_men', 'population_percent_of_single_women', 'population', 'edu_average_scale_score', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt', 'fatalities_mpmt', 'injuries_mpmt', 'walk_score', 'transit_score', 'bike_score', 'unemploymentrate', 'employment', 'laborforce']
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.09s    186   0.229   1.000   0.373   0.000   0.000    0.130
# minibatchk-means   0.06s    191   0.236   1.000   0.382   0.000   0.000    0.088
#      Ward   0.01s          Na    0.213   1.000   0.352   0.000   0.000    0.102
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    176   0.269   1.000   0.424   0.000   0.000    0.105
# minibatchk-means   0.06s    180   0.275   1.000   0.431   0.000   0.000    0.085
#      Ward   0.01s          Na    0.241   1.000   0.389   0.000   0.000    0.100
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.13s    169   0.299   1.000   0.460   0.000   0.000    0.111
# minibatchk-means   0.06s    175   0.273   1.000   0.429   0.000   0.000    0.116
#      Ward   0.01s          Na    0.251   1.000   0.401   0.000   0.000    0.107
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.11s    162   0.332   1.000   0.499   0.000   0.000    0.094
# minibatchk-means   0.06s    169   0.333   1.000   0.500   0.000   0.000    0.066
#      Ward   0.01s          Na    0.272   1.000   0.428   0.000   0.000    0.102
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.15s    156   0.334   1.000   0.500   0.000   0.000    0.102
# minibatchk-means   0.08s    164   0.355   1.000   0.524   0.000   0.000    0.077
#      Ward   0.01s          Na    0.310   1.000   0.473   0.000   0.000    0.094
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.14s    151   0.325   1.000   0.490   0.000   0.000    0.116
# minibatchk-means   0.13s    152   0.343   1.000   0.510   0.000   0.000    0.115
#      Ward   0.01s          Na    0.332   1.000   0.499   0.000   0.000    0.095
# _____________________________________________________________________
# ********************
# Modeling used for feature selection : Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
# ********************
# ['murder_manslaughter', 'rent_burden', 'median_age_of_men', 'median_age_of_women', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt', 'fatalities_mpmt', 'unemploymentrate']
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.09s    34   0.205   1.000   0.340   0.000   0.000    0.205
# minibatchk-means   0.06s    34   0.185   1.000   0.313   0.000   0.000    0.227
#      Ward   0.01s          Na    0.140   1.000   0.245   0.000   0.000    0.249
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.14s    31   0.245   1.000   0.394   0.000   0.000    0.158
# minibatchk-means   0.04s    32   0.256   1.000   0.408   0.000   0.000    0.121
#      Ward   0.00s          Na    0.225   1.000   0.368   0.000   0.000    0.115
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.12s    29   0.236   1.000   0.382   0.000   0.000    0.163
# minibatchk-means   0.06s    30   0.283   1.000   0.441   0.000   0.000    0.139
#      Ward   0.00s          Na    0.249   1.000   0.399   0.000   0.000    0.130
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.11s    26   0.280   1.000   0.437   0.000   0.000    0.166
# minibatchk-means   0.06s    28   0.268   1.000   0.422   0.000   0.000    0.160
#      Ward   0.00s          Na    0.253   1.000   0.404   0.000   0.000    0.133
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.10s    24   0.315   1.000   0.479   0.000   0.000    0.162
# minibatchk-means   0.05s    25   0.311   1.000   0.475   0.000   0.000    0.142
#      Ward   0.01s          Na    0.301   1.000   0.463   0.000   0.000    0.123
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    23   0.334   1.000   0.501   0.000   0.000    0.170
# minibatchk-means   0.06s    25   0.343   1.000   0.511   0.000   0.000    0.134
#      Ward   0.00s          Na    0.320   1.000   0.485   0.000   0.000    0.135
# _____________________________________________________________________
# ********************
# Modeling used for feature selection : ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)
# ********************
# ['murder_manslaughter', 'rent_burden', 'mortgage_burden', 'median_age_of_men', 'median_age_of_women', 'population_percent_of_single_men', 'population_percent_of_single_women', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt']
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    42   0.210   1.000   0.347   0.000   0.000    0.190
# minibatchk-means   0.05s    43   0.198   1.000   0.330   0.000   0.000    0.199
#      Ward   0.00s          Na    0.194   1.000   0.325   0.000   0.000    0.158
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.12s    39   0.261   1.000   0.413   0.000   0.000    0.152
# minibatchk-means   0.04s    42   0.263   1.000   0.416   0.000   0.000    0.130
#      Ward   0.00s          Na    0.260   1.000   0.413   0.000   0.000    0.087
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.12s    35   0.275   1.000   0.432   0.000   0.000    0.168
# minibatchk-means   0.05s    38   0.279   1.000   0.436   0.000   0.000    0.133
#      Ward   0.00s          Na    0.264   1.000   0.418   0.000   0.000    0.097
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.10s    33   0.277   1.000   0.434   0.000   0.000    0.176
# minibatchk-means   0.08s    34   0.302   1.000   0.463   0.000   0.000    0.154
#      Ward   0.00s          Na    0.284   1.000   0.443   0.000   0.000    0.118
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.12s    32   0.315   1.000   0.480   0.000   0.000    0.154
# minibatchk-means   0.08s    32   0.319   1.000   0.484   0.000   0.000    0.147
#      Ward   0.00s          Na    0.291   1.000   0.451   0.000   0.000    0.123
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.10s    29   0.326   1.000   0.492   0.000   0.000    0.158
# minibatchk-means   0.07s    30   0.336   1.000   0.503   0.000   0.000    0.144
#      Ward   0.01s          Na    0.318   1.000   0.482   0.000   0.000    0.128
# _____________________________________________________________________

# %%
featuresx.head()
# Out:
#    violent_crime_rate  murder_manslaughter  rape  robbery  aggravated_assault  \
# 0               371.4                  3.1  16.6    135.3               216.3
# 1               368.9                  4.4  21.6    136.6               206.2
# 2               380.1                  6.3  28.2    143.3               202.2
# 3               332.9                  4.4  31.8    120.8               175.8
# 4               567.4                  5.8  33.2    232.2               296.1
#
#    property_crime_rate  burglary  larceny_theft  motor_vehicle_theft  \
# 0               1609.9    220.80         1254.4                100.8
# 1               2050.4    402.80         1324.6                323.0
# 2               2135.4    361.70         1605.9                167.9
# 3               3036.4    525.15         2071.8                263.3
# 4               3208.1    688.60         2132.6                387.0
#
#    total_crime_rate     ...      pct_laccess_hhnv10  event_mpmt  \
# 0            1981.3     ...                0.338235    0.418116
# 1            2419.3     ...                0.224680    0.298524
# 2            2515.5     ...                0.473720    0.579050
# 3            3369.3     ...                0.650693    0.494725
# 4            3775.5     ...                3.322921    0.492627
#
#    fatalities_mpmt  injuries_mpmt  walk_score  transit_score  bike_score  \
# 0         0.005243       0.396239   74.500000      44.833333   30.333333
# 1         0.004415       0.345391   60.052632      19.368421   24.000000
# 2         0.004533       0.708461   49.700000      20.300000    7.000000
# 3         0.006083       0.583938   38.714286      19.714286   26.285714
# 4         0.001631       0.724259   29.000000       7.400000    9.800000
#
#    unemploymentrate  employment  laborforce
# 0              6.40   9324454.0   9965273.0
# 1              6.75   6932227.5   7426637.5
# 2              7.10   4540001.0   4888002.0
# 3              5.00   3357271.0   3534675.0
# 4              5.00   3079095.0   3239227.0
#
# [5 rows x 40 columns]

# %% [markdown]
# # Part 4:
# * Features ran through PCA (Principal Component Analysis)
# * Used Unscaled Data, Data ran through Standard Scaler and Min Max Scaler
# * Loop through K-Means Clustering, K-Means MiniBatch, and then Aggomerative Clustering with linkage default ward.
# * Features used were subset through Lasso, Ridge and ElasticNet

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
print (20 * '*')
print (20 * '*')
print ('DATA RAN THROUGH PCA')
print (20 * '*')
print (20 * '*')


###############
## PCA SCALE##
###############

pca = PCA(n_components = 21) ## half of the features + 1 this is the standard
pca_features = pca.fit(featuresx).transform(featuresx)
#pca_features = pd.DataFrame(pca_feat)
#pca.columns = ['violent_crime_rate', 'murder_manslaughter', 'rape', 'robbery', 'aggravated_assault', 'property_crime_rate', 'burglary', 'larceny_theft', 'motor_vehicle_theft', 'total_crime_rate', 'median_gross_rent', 'median_monthly_mortgage', 'rent_burden', 'mortgage_burden', 'income_change_2012_to_2014', 'median_age_of_men', 'median_age_of_women', 'median_age', 'median_household_income', 'single_men_population', 'single_women_population', 'ratio_of_single_men_to_single_women', 'population_percent_of_single_men', 'population_percent_of_single_women', 'population', 'edu_average_scale_score', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt', 'fatalities_mpmt', 'injuries_mpmt', 'walk_score', 'transit_score', 'bike_score', 'unemploymentrate', 'employment', 'laborforce']

################
# pca_features
################
print (20 * '*')
print ('pca unscaled data')
print (20 * '*')
    
range_n_clusters = [4,5,6,7,8,9]
features = pca_features

for n_clusters in range_n_clusters:
    print ('number of clusters: %d' % (n_clusters))
    print(69 * '_')
    print('% 9s' % 'name'
          '    time  inertia    homo   compl  v-meas     ARI AMI  silhouette')


    def bench_clustering(estimator, name, data):
        t0 = time()
        estimator.fit(data)
        try: 
            print('% 9s   %.2fs    %i   %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
              % (name, (time() - t0), estimator.inertia_,
                 metrics.homogeneity_score(labelsx, estimator.labels_),
                 metrics.completeness_score(labelsx, estimator.labels_),
                 metrics.v_measure_score(labelsx, estimator.labels_),
                 metrics.adjusted_rand_score(labelsx, estimator.labels_),
                 metrics.adjusted_mutual_info_score(labelsx,  estimator.labels_),
                 metrics.silhouette_score(data, estimator.labels_)))
        except AttributeError:
            print('% 9s   %.2fs   %9s    %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
              % (name, (time() - t0), "Na",
                 metrics.homogeneity_score(labelsx, estimator.labels_),
                 metrics.completeness_score(labelsx, estimator.labels_),
                 metrics.v_measure_score(labelsx, estimator.labels_),
                 metrics.adjusted_rand_score(labelsx, estimator.labels_),
                 metrics.adjusted_mutual_info_score(labelsx,  estimator.labels_),
                 metrics.silhouette_score(data, estimator.labels_)))

    bench_clustering(KMeans(init='k-means++', n_clusters=n_clusters, n_init=12),
              name="k-means", data=features)
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        bench_clustering(MiniBatchKMeans(init='k-means++', n_clusters=n_clusters, n_init=12,max_no_improvement=10, verbose=0,
                  random_state=0), name="minibatchk-means", data=features)
                         
    bench_clustering(AgglomerativeClustering(n_clusters=n_clusters, linkage='ward'),
              name="Ward", data=features)         


    print(69 * '_')

feat_scales = [StandardScaler(), MinMaxScaler()]

for feat_scale in feat_scales:
    print (20 * '*')
    print ('Scaled data for PCA : yes : %s' % (feat_scale))
    print (20 * '*')
    
    ## still use featurex is because we are scaling data for feature modeling only
    stdfeat = feat_scale.fit_transform(featuresx)  ## turns into scaled array
    stdfeatures = pd.DataFrame(stdfeat) ## make array pd again

    pca = PCA(n_components = 2)
    pca_stdfeatures = pca.fit(stdfeatures).transform(stdfeatures)
    #pca_features = pd.DataFrame(pca_feat)
    #pca.columns = ['violent_crime_rate', 'murder_manslaughter', 'rape', 'robbery', 'aggravated_assault', 'property_crime_rate', 'burglary', 'larceny_theft', 'motor_vehicle_theft', 'total_crime_rate', 'median_gross_rent', 'median_monthly_mortgage', 'rent_burden', 'mortgage_burden', 'income_change_2012_to_2014', 'median_age_of_men', 'median_age_of_women', 'median_age', 'median_household_income', 'single_men_population', 'single_women_population', 'ratio_of_single_men_to_single_women', 'population_percent_of_single_men', 'population_percent_of_single_women', 'population', 'edu_average_scale_score', 'pct_laccess_pop10', 'pct_laccess_lowi10', 'pct_laccess_child10', 'pct_laccess_seniors10', 'pct_laccess_hhnv10', 'event_mpmt', 'fatalities_mpmt', 'injuries_mpmt', 'walk_score', 'transit_score', 'bike_score', 'unemploymentrate', 'employment', 'laborforce']


    features = pca_stdfeatures
    for n_clusters in range_n_clusters:
        print ('number of clusters: %d' % (n_clusters))
        print(69 * '_')
        print('% 9s' % 'name'
              '    time  inertia    homo   compl  v-meas     ARI AMI  silhouette')

        def bench_clustering(estimator, name, data):
            t0 = time()
            estimator.fit(data)
            
            try: 
                print('% 9s   %.2fs    %i   %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
                  % (name, (time() - t0), estimator.inertia_,
                     metrics.homogeneity_score(labelsx, estimator.labels_),
                     metrics.completeness_score(labelsx, estimator.labels_),
                     metrics.v_measure_score(labelsx, estimator.labels_),
                     metrics.adjusted_rand_score(labelsx, estimator.labels_),
                     metrics.adjusted_mutual_info_score(labelsx,  estimator.labels_),
                     metrics.silhouette_score(data, estimator.labels_)))
            except AttributeError:
                print('% 9s   %.2fs   %9s    %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
                  % (name, (time() - t0), "Na",
                     metrics.homogeneity_score(labelsx, estimator.labels_),
                     metrics.completeness_score(labelsx, estimator.labels_),
                     metrics.v_measure_score(labelsx, estimator.labels_),
                     metrics.adjusted_rand_score(labelsx, estimator.labels_),
                     metrics.adjusted_mutual_info_score(labelsx,  estimator.labels_),
                     metrics.silhouette_score(data, estimator.labels_)))

        bench_clustering(KMeans(init='k-means++', n_clusters=n_clusters, n_init=12),
                  name="k-means", data=features)
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            bench_clustering(MiniBatchKMeans(init='k-means++', n_clusters=n_clusters, n_init=12,max_no_improvement=10, verbose=0,
                      random_state=0), name="minibatchk-means", data=features)

        bench_clustering(AgglomerativeClustering(n_clusters=n_clusters, linkage='ward'),
                  name="Ward", data=features)   
        
        print(69 * '_')
# Out:
# ********************
# ********************
# DATA RAN THROUGH PCA
# ********************
# ********************
# ********************
# pca unscaled data
# ********************
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.04s    113673701468201   0.089   1.000   0.163   0.000   0.000    0.795
# minibatchk-means   0.03s    115592694079857   0.097   1.000   0.177   0.000   0.000    0.781
#      Ward   0.00s          Na    0.083   1.000   0.153   0.000   0.000    0.791
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.04s    72526519715513   0.091   1.000   0.166   0.000   0.000    0.798
# minibatchk-means   0.05s    74050897830407   0.104   1.000   0.189   0.000   0.000    0.774
#      Ward   0.01s          Na    0.084   1.000   0.155   0.000   0.000    0.795
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.07s    48843095833178   0.165   1.000   0.283   0.000   0.000    0.683
# minibatchk-means   0.05s    51959584713527   0.151   1.000   0.262   0.000   0.000    0.686
#      Ward   0.01s          Na    0.146   1.000   0.255   0.000   0.000    0.688
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.07s    34295807848014   0.170   1.000   0.291   0.000   0.000    0.686
# minibatchk-means   0.04s    35649852425732   0.171   1.000   0.292   0.000   0.000    0.684
#      Ward   0.00s          Na    0.147   1.000   0.256   0.000   0.000    0.692
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.09s    19273737754266   0.172   1.000   0.293   0.000   0.000    0.693
# minibatchk-means   0.06s    351599210018305   0.330   1.000   0.497   0.000   0.000    0.405
#      Ward   0.00s          Na    0.152   1.000   0.263   0.000   0.000    0.693
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.09s    14014636824443   0.205   1.000   0.341   0.000   0.000    0.656
# minibatchk-means   0.06s    393038115761406   0.281   1.000   0.438   0.000   0.000    0.536
#      Ward   0.00s          Na    0.160   1.000   0.275   0.000   0.000    0.697
# _____________________________________________________________________
# ********************
# Scaled data for PCA : yes : StandardScaler(copy=True, with_mean=True, with_std=True)
# ********************
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.06s    1337   0.172   1.000   0.294   0.000   0.000    0.414
# minibatchk-means   0.03s    1346   0.180   1.000   0.305   0.000   0.000    0.408
#      Ward   0.00s          Na    0.192   1.000   0.322   0.000   0.000    0.379
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.07s    1028   0.228   1.000   0.371   0.000   0.000    0.364
# minibatchk-means   0.04s    1078   0.234   1.000   0.380   0.000   0.000    0.365
#      Ward   0.00s          Na    0.214   1.000   0.353   0.000   0.000    0.372
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    817   0.270   1.000   0.425   0.000   0.000    0.377
# minibatchk-means   0.04s    834   0.267   1.000   0.421   0.000   0.000    0.370
#      Ward   0.01s          Na    0.269   1.000   0.423   0.000   0.000    0.353
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.08s    671   0.302   1.000   0.463   0.000   0.000    0.385
# minibatchk-means   0.05s    711   0.306   1.000   0.469   0.000   0.000    0.348
#      Ward   0.00s          Na    0.297   1.000   0.459   0.000   0.000    0.377
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.07s    596   0.330   1.000   0.496   0.000   0.000    0.367
# minibatchk-means   0.11s    636   0.314   1.000   0.477   0.000   0.000    0.350
#      Ward   0.01s          Na    0.334   1.000   0.501   0.000   0.000    0.330
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.09s    527   0.358   1.000   0.527   0.000   0.000    0.344
# minibatchk-means   0.08s    557   0.345   1.000   0.513   0.000   0.000    0.324
#      Ward   0.01s          Na    0.355   1.000   0.524   0.000   0.000    0.337
# _____________________________________________________________________
# ********************
# Scaled data for PCA : yes : MinMaxScaler(copy=True, feature_range=(0, 1))
# ********************
# number of clusters: 4
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.09s    30   0.239   1.000   0.386   0.000   0.000    0.363
# minibatchk-means   0.04s    30   0.241   1.000   0.388   0.000   0.000    0.359
#      Ward   0.01s          Na    0.241   1.000   0.388   0.000   0.000    0.327
# _____________________________________________________________________
# number of clusters: 5
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.06s    23   0.270   1.000   0.425   0.000   0.000    0.381
# minibatchk-means   0.05s    27   0.280   1.000   0.438   0.000   0.000    0.299
#      Ward   0.01s          Na    0.264   1.000   0.417   0.000   0.000    0.340
# _____________________________________________________________________
# number of clusters: 6
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.13s    20   0.291   1.000   0.450   0.000   0.000    0.379
# minibatchk-means   0.07s    21   0.307   1.000   0.470   0.000   0.000    0.331
#      Ward   0.00s          Na    0.289   1.000   0.449   0.000   0.000    0.355
# _____________________________________________________________________
# number of clusters: 7
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.07s    17   0.328   1.000   0.494   0.000   0.000    0.357
# minibatchk-means   0.05s    17   0.326   1.000   0.491   0.000   0.000    0.356
#      Ward   0.01s          Na    0.316   1.000   0.481   0.000   0.000    0.337
# _____________________________________________________________________
# number of clusters: 8
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.07s    14   0.356   1.000   0.525   0.000   0.000    0.361
# minibatchk-means   0.06s    15   0.349   1.000   0.517   0.000   0.000    0.326
#      Ward   0.01s          Na    0.352   1.000   0.520   0.000   0.000    0.331
# _____________________________________________________________________
# number of clusters: 9
# _____________________________________________________________________
# name    time  inertia    homo   compl  v-meas     ARI AMI  silhouette
#   k-means   0.10s    13   0.370   1.000   0.540   0.000   0.000    0.354
# minibatchk-means   0.07s    13   0.373   1.000   0.543   0.000   0.000    0.343
#      Ward   0.00s          Na    0.369   1.000   0.539   0.000   0.000    0.326
# _____________________________________________________________________
